# %% [markdown]
# # Print

# %%
print("Hello")
print("World")
print("Goood")
print("Bye")
# Out:
# Hello
# World
# Goood
# Bye

# %%
print("Hello",end=' ')
print("World",end=' ')
print("Goood",end=' ')
print("Bye")
# Out:
# Hello World Goood Bye

# %% [markdown]
# # Multiple assignments

# %%
p = 30
q = 20
p, q = 20, 30
p,q=q,p
p,q
# Out:
# (30, 20)

# %% [markdown]
# # Input

# %%
a=input("Enter the Number:")
b=int(input("Enter the Number:"))
c=eval(input("Enter the Number:"))
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# # Formatting number and strings

# %%
x = 20.345123
x = format(x, ".3f")
x = 20.345123
x = format(x, "7.3f")
x = 20.345123
x = format(x, "<7.3f")
# here format function return a string value
x
# Out:
# '20.345 '
